# %%
# %matplotlib inline
import diff_aug
from diff_aug import aug
from tqdm.auto import tqdm
from importlib import reload
reload(diff_aug)
import diff_aug
from diff_aug import aug


model_names = [#'BNN',
               #'NF',
               'NN (pytorch)',
               'NN (sklearn)',
               'GP',
               'GP C(1.0)*RBF([1.0, 1.0]) + Matern() + WhiteKernel()',
               'GP C(1.0)*Matern() * RBF([1, 1]) + Matern() + WhiteKernel()']
               
for model in tqdm(model_names):
    aug(model_name = model)
# Out:
# Количество объектов:  1870
# ...
# 0it [00:00, ?it/s]
# NN (pytorch)
# 1219it [21:43,  1.51s/it]
# 1870it [34:30,  1.11s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
# Среднее время работы для 1-го объекта (fit, predict,augmentation): 1.0884381134879781
#  10%|█         | 1/10 [00:01<00:15,  1.76s/it]
# Среднее значение метрики RMSE 0.020863717141251518 +- 0.00407335955499574
#  20%|██        | 2/10 [00:03<00:13,  1.74s/it]
# Среднее значение метрики MAE 0.01662445062644587 +- 0.0032041009237025173
#  30%|███       | 3/10 [00:05<00:12,  1.73s/it]
# Среднее значение метрики RSE 0.7515986658176915 +- 0.11155710784276263
#  40%|████      | 4/10 [00:06<00:10,  1.71s/it]
# Среднее значение метрики RAE 0.6999345060334172 +- 0.10626791630010418
#  50%|█████     | 5/10 [00:08<00:08,  1.70s/it]
# Среднее значение метрики MAPE 12.281200606870318 +- 2.4847973083863053
#  60%|██████    | 6/10 [00:10<00:06,  1.71s/it]
# Среднее значение метрики NLPD 7.310242917714669 +- 3.5089603106910574
# ...

# %%
aug(model_name = 'BNN')
# Out:
# 0it [00:00, ?it/s]
# BNN
# 1219it [1:32:46,  4.64s/it]
# 1870it [2:26:49,  4.71s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
# Среднее время работы для 1-го объекта (fit, predict,augmentation): 4.693439933322968
#  10%|█         | 1/10 [00:03<00:32,  3.61s/it]
# Среднее значение метрики RMSE 0.02389655978953495 +- 0.0061886108309658575
#  20%|██        | 2/10 [00:07<00:28,  3.57s/it]
# Среднее значение метрики MAE 0.01989217583033569 +- 0.005551621252563351
#  30%|███       | 3/10 [00:10<00:24,  3.52s/it]
# Среднее значение метрики RSE 0.849677025220826 +- 0.15823856614327755
#  40%|████      | 4/10 [00:13<00:20,  3.49s/it]
# Среднее значение метрики RAE 0.8017991520877232 +- 0.15217455635283042
#  50%|█████     | 5/10 [00:17<00:17,  3.50s/it]
# Среднее значение метрики MAPE 10.987153535574054 +- 0.36791480928354847
#  60%|██████    | 6/10 [00:21<00:14,  3.53s/it]
# Среднее значение метрики NLPD 35.16514714453844 +- 3.4920736832032846
# ...

# %%
# %matplotlib inline
import diff_aug
from diff_aug import aug
from tqdm.auto import tqdm
from importlib import reload
reload(diff_aug)
import diff_aug
from diff_aug import aug


aug(model_name = 'NF')
# Out:
# 0it [00:00, ?it/s]
# Количество объектов:  1870
# NF
# 1219it [14:19:10, 21.63s/it]
# 1870it [18:12:41, 35.06s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
# Среднее время работы для 1-го объекта (fit, predict,augmentation): 35.029822600206586
#  10%|█         | 1/10 [00:01<00:15,  1.72s/it]
# Среднее значение метрики RMSE 0.03262562062080115 +- 0.01047840929323637
#  20%|██        | 2/10 [00:03<00:13,  1.71s/it]
# Среднее значение метрики MAE 0.02704134447805318 +- 0.009132362421230588
#  30%|███       | 3/10 [00:05<00:12,  1.74s/it]
# Среднее значение метрики RSE 0.7903773845328388 +- 0.13637474934988472
#  40%|████      | 4/10 [00:06<00:10,  1.73s/it]
# Среднее значение метрики RAE 0.7345089234922189 +- 0.11928666743107987
#  50%|█████     | 5/10 [00:08<00:08,  1.71s/it]
# Среднее значение метрики MAPE 10.299929013723556 +- 0.2730374469820464
#  60%|██████    | 6/10 [00:10<00:06,  1.71s/it]
# Среднее значение метрики NLPD -2.8597911529278606 +- 0.03670672020119681
# ...

# %% [markdown]
# # Test_train_split has bin_size = 5, tests_bins = 2 (higher results with bin_size = 3, tests_bins = 2)

# %%
# %matplotlib inline
import diff_aug
from diff_aug import aug
#from tqdm.auto import tqdm
from tqdm import tqdm
from importlib import reload
reload(diff_aug)
import diff_aug
from diff_aug import aug_all


model_names = [
               'NN (pytorch)',
               'NN (sklearn)',
               'GP',
               'GP C(1.0)*RBF([1.0, 1.0]) + Matern() + WhiteKernel()',
               'GP C(1.0)*Matern() * RBF([1, 1]) + Matern() + WhiteKernel()',
                'BNN', 
                'NF'
]
reports = []               
for model in tqdm(model_names):
    report = aug_all(model_name = model)
    reports.append(report)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# Количество объектов:  1870
# NN (pytorch)
#   0%|          | 0/10 [00:00<?, ?it/s]
# <class 'list'>
# <class 'float'>
# На train_test_split упало 7 объектов
# 1863
#  10%|█         | 1/10 [00:01<00:15,  1.76s/it]
# Среднее значение метрики RMSE 0.018477809989090505 +- 0.0009243978655873683
#  20%|██        | 2/10 [00:03<00:14,  1.79s/it]
# Среднее значение метрики MAE 0.014746361606538099 +- 0.0007323525129072513
#  30%|███       | 3/10 [00:05<00:12,  1.78s/it]
# Среднее значение метрики RSE 0.7164344341706622 +- 0.049619839378039286
#  40%|████      | 4/10 [00:07<00:10,  1.77s/it]
# Среднее значение метрики RAE 0.6887003550636023 +- 0.04762045183368385
#  50%|█████     | 5/10 [00:08<00:08,  1.78s/it]
# Среднее значение метрики MAPE 10.97970929132889 +- 0.29595294844674963
#  60%|██████    | 6/10 [00:10<00:07,  1.77s/it]
# Среднее значение метрики NLPD 15.327041993581496 +- 2.454276743409154
#  70%|███████   | 7/10 [00:12<00:05,  1.77s/it]
# ...

# %%
import numpy as np


for model_name, info  in zip(model_names, reports):
    #print(type(info), info.columns)
    print(model_name, "Mean time of (fit, predict,augmentation) for 1 obj = {} seconds".format(np.round(np.mean(info['t'].values),2)))
# Out:
# NN (pytorch) Mean time of (fit, predict,augmentation) for 1 obj = 1.52 seconds
# NN (sklearn) Mean time of (fit, predict,augmentation) for 1 obj = 0.07 seconds
# GP Mean time of (fit, predict,augmentation) for 1 obj = 0.39 seconds
# GP C(1.0)*RBF([1.0, 1.0]) + Matern() + WhiteKernel() Mean time of (fit, predict,augmentation) for 1 obj = 0.69 seconds
# GP C(1.0)*Matern() * RBF([1, 1]) + Matern() + WhiteKernel() Mean time of (fit, predict,augmentation) for 1 obj = 1.19 seconds
# BNN Mean time of (fit, predict,augmentation) for 1 obj = 8.89 seconds
# NF Mean time of (fit, predict,augmentation) for 1 obj = 41.31 seconds

# %%
import matplotlib.pyplot as plt


for model_name, info  in zip(model_names, reports):
    for metric in info.columns[1:12]:
        plt.hist(info[metric].values)

        plt.title(model_name +  ' '  + metric)
        plt.show()

# %%
for model_name, info  in zip(model_names, reports):
    df_all = pd.read_csv(path + '/ANTARES_NEW.csv')
    all_names = df_all['object_id'].unique()
    names_good = info['name'].values
    difference = np.setdiff1d(all_names, names_good)
    print(model_name, difference)
# Out:
# NN (pytorch) ['ZTF19acqypso' 'ZTF20aannodx' 'ZTF20abqgbum' 'ZTF21aaabvkj'
#  'ZTF21aaafgmv' 'ZTF21aaahliy' 'ZTF21abwxaht']
# NN (sklearn) ['ZTF19acqypso' 'ZTF20aannodx' 'ZTF20abqgbum' 'ZTF21aaabvkj'
#  'ZTF21aaafgmv' 'ZTF21aaahliy' 'ZTF21abwxaht']
# GP ['ZTF19acqypso' 'ZTF20aannodx' 'ZTF20abqgbum' 'ZTF21aaabvkj'
#  'ZTF21aaafgmv' 'ZTF21aaahliy' 'ZTF21abwxaht']
# GP C(1.0)*RBF([1.0, 1.0]) + Matern() + WhiteKernel() ['ZTF19acqypso' 'ZTF20aannodx' 'ZTF20abqgbum' 'ZTF21aaabvkj'
#  'ZTF21aaafgmv' 'ZTF21aaahliy' 'ZTF21abwxaht']
# GP C(1.0)*Matern() * RBF([1, 1]) + Matern() + WhiteKernel() ['ZTF19acqypso' 'ZTF20aannodx' 'ZTF20abqgbum' 'ZTF21aaabvkj'
#  'ZTF21aaafgmv' 'ZTF21aaahliy' 'ZTF21abwxaht']
# BNN ['ZTF19acqypso' 'ZTF20aannodx' 'ZTF20abqgbum' 'ZTF21aaabvkj'
#  'ZTF21aaafgmv' 'ZTF21aaahliy' 'ZTF21abwxaht']
# NF ['ZTF19acqypso' 'ZTF20aannodx' 'ZTF20abqgbum' 'ZTF21aaabvkj'
#  'ZTF21aaafgmv' 'ZTF21aaahliy' 'ZTF21abwxaht']

# %%
difference
# Out:
# array(['ZTF19acqypso', 'ZTF20aannodx', 'ZTF20abqgbum', 'ZTF21aaabvkj',
#        'ZTF21aaafgmv', 'ZTF21aaahliy', 'ZTF21abwxaht'], dtype=object)

# %%
for obj in difference:
    anobj_r = df_all[(df_all['object_id'] == obj)&(df_all['passband'] == 1)]
    anobj_g = df_all[(df_all['object_id'] == obj)&(df_all['passband'] == 0)]
    plt.title(obj)
    plt.errorbar(anobj_r['mjd'], anobj_r['flux'], yerr=anobj_r['flux_err'], fmt = 'o', color='red')
    plt.errorbar(anobj_g['mjd'], anobj_g['flux'], yerr=anobj_g['flux_err'], fmt = 'o', color='green')
    plt.show()

# %% [markdown]
# # Попробуем опять bin_size = 3, tests_bin = 2, надо понять откуда там nan появлялись в  GP со сложными ядрами

# %%
# %matplotlib inline
import diff_aug
from diff_aug import aug
#from tqdm.auto import tqdm
from tqdm import tqdm
from importlib import reload
reload(diff_aug)
import diff_aug
from diff_aug import aug_all


model_names = [
               'NN (pytorch)',
               'NN (sklearn)',
               'GP',
               'GP C(1.0)*RBF([1.0, 1.0]) + Matern() + WhiteKernel()',
               'GP C(1.0)*Matern() * RBF([1, 1]) + Matern() + WhiteKernel()',
                'BNN', 
                'NF'
]
reports = []               
for model in tqdm(model_names):
    report = aug_all(model_name = model)
    reports.append(report)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
# Количество объектов:  1870
# NN (pytorch)
#   0%|          | 0/10 [00:00<?, ?it/s]
# <class 'list'>
# <class 'int'>
# На train_test_split упало 0 объектов
# 1870
#  10%|█         | 1/10 [00:01<00:16,  1.84s/it]
# Среднее значение метрики RMSE 0.020263551631865526 +- 0.0038727086696193017
#  20%|██        | 2/10 [00:03<00:14,  1.86s/it]
# Среднее значение метрики MAE 0.01609971365604896 +- 0.0029751297087740906
#  30%|███       | 3/10 [00:05<00:13,  1.89s/it]
# Среднее значение метрики RSE 0.796104145771889 +- 0.14731435384368058
#  40%|████      | 4/10 [00:07<00:11,  1.95s/it]
# Среднее значение метрики RAE 0.7408671716385529 +- 0.13877897425407687
#  50%|█████     | 5/10 [00:09<00:09,  1.91s/it]
# Среднее значение метрики MAPE 10.133241561188393 +- 0.2727587740393592
#  60%|██████    | 6/10 [00:11<00:07,  1.90s/it]
# Среднее значение метрики NLPD 4.608411672187555 +- 1.559449182143156
#  70%|███████   | 7/10 [00:13<00:05,  1.89s/it]
# ...

# %%
for model_name, info  in zip(model_names, reports):
    
    print(model_name, "Mean time of (fit, predict,augmentation) for 1 obj = {} seconds".format(np.round(np.mean(info['t'].values),2)))
# Out:
# NN (pytorch) Mean time of (fit, predict,augmentation) for 1 obj = 2.31 seconds
# NN (sklearn) Mean time of (fit, predict,augmentation) for 1 obj = 0.12 seconds
# GP Mean time of (fit, predict,augmentation) for 1 obj = 0.66 seconds
# GP C(1.0)*RBF([1.0, 1.0]) + Matern() + WhiteKernel() Mean time of (fit, predict,augmentation) for 1 obj = 1.16 seconds
# GP C(1.0)*Matern() * RBF([1, 1]) + Matern() + WhiteKernel() Mean time of (fit, predict,augmentation) for 1 obj = 1.99 seconds
# BNN Mean time of (fit, predict,augmentation) for 1 obj = 9.95 seconds
# NF Mean time of (fit, predict,augmentation) for 1 obj = 46.15 seconds

# %%
for model_name, info  in zip(model_names, reports):
    for metric in info.columns[1:12]:
        plt.hist(info[metric].values)

        plt.title(model_name +  ' '  + metric)
        plt.show()
