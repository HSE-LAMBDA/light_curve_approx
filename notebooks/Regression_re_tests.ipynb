# %%
# %matplotlib inline
import diff_aug_re
from diff_aug_re import aug
from tqdm.auto import tqdm
from importlib import reload
reload(diff_aug_re)
import diff_aug_re
from diff_aug_re import aug

model_names = ['BNN',
               'NF',
               'NN (pytorch)',
               'NN (sklearn)',
               'GP',
               'GP C(1.0)*RBF([1.0, 1.0]) + Matern() + WhiteKernel()',
               'GP C(1.0)*Matern() * RBF([1, 1]) + Matern() + WhiteKernel()']#,
               #'GP with err',
               #'GP C(1.0)*RBF([1.0, 1.0]) + Matern() + WhiteKernel() with err',
               #'GP C(1.0)*Matern() * RBF([1, 1]) + Matern() + WhiteKernel() with err']
#n_observations = [50, 100, 500, 1000, 1500, 2000]
#test_sizes = [i for i in range(0.1, 0.6, 0.1)]
for model in tqdm(model_names):
    aug(model_name = model)#, N_OBS = n, TEST_SIZE = t)
# Out:
# Количество объектов:  3111
# ...
# 0it [00:00, ?it/s]
# BNN
# 1757it [2:14:53,  4.50s/it]
# 3111it [3:56:45,  4.57s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
# Среднее время работы для 1-го объекта (fit, predict,augmentation): 4.548918638456216
#  10%|█         | 1/10 [00:03<00:29,  3.29s/it]
# Среднее значение метрики RMSE 0.04038572327797111 +- 0.003315994253601582
#  20%|██        | 2/10 [00:06<00:26,  3.27s/it]
# Среднее значение метрики MAE 0.02612856866427685 +- 0.0015437367506717407
#  30%|███       | 3/10 [00:09<00:22,  3.26s/it]
# Среднее значение метрики RSE 0.5709466023623362 +- 0.008815638866323333
#  40%|████      | 4/10 [00:12<00:19,  3.24s/it]
# Среднее значение метрики RAE 0.4948397170302662 +- 0.008186588026149156
#  50%|█████     | 5/10 [00:16<00:16,  3.23s/it]
# Среднее значение метрики MAPE 19.273425623771438 +- 0.3376956525962165
#  60%|██████    | 6/10 [00:19<00:12,  3.21s/it]
# Среднее значение метрики NLPD 260.93508380691685 +- 11.337725842760332
# ...

# %%
# %matplotlib inline
import diff_aug_re
from diff_aug_re import aug
from tqdm.auto import tqdm
from importlib import reload
reload(diff_aug_re)
import diff_aug_re
from diff_aug_re import aug

model_names = ['BNN',
               'NF',
               'NN (pytorch)',
               'NN (sklearn)',
               'GP',
               'GP C(1.0)*RBF([1.0, 1.0]) + Matern() + WhiteKernel()',
               'GP C(1.0)*Matern() * RBF([1, 1]) + Matern() + WhiteKernel()']
for model in tqdm(model_names[1:]):
    aug(model_name = model)
# Out:
# Количество объектов:  3111
# ...
# 0it [00:00, ?it/s]
# NF
# 1757it [10:18:39, 20.67s/it]
# 3111it [17:54:46, 20.73s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
# Среднее время работы для 1-го объекта (fit, predict,augmentation): 20.70777229073346
#  10%|█         | 1/10 [00:03<00:28,  3.13s/it]
# Среднее значение метрики RMSE 0.04051255189715405 +- 0.004352799838876988
#  20%|██        | 2/10 [00:06<00:24,  3.10s/it]
# Среднее значение метрики MAE 0.024283314905585638 +- 0.0016743414858245394
#  30%|███       | 3/10 [00:09<00:21,  3.07s/it]
# Среднее значение метрики RSE 0.5112420717203691 +- 0.007636020360111601
#  40%|████      | 4/10 [00:12<00:18,  3.07s/it]
# Среднее значение метрики RAE 0.44296629811025323 +- 0.0067996110576199545
#  50%|█████     | 5/10 [00:15<00:15,  3.05s/it]
# Среднее значение метрики MAPE 16.677555918426002 +- 0.2917503932178474
#  60%|██████    | 6/10 [00:18<00:12,  3.08s/it]
# Среднее значение метрики NLPD -0.2075472245663968 +- 0.25129069960080536
# ...

# %%
aug(model_name = 'GP C(1.0)*Matern() * RBF([1, 1]) + Matern() + WhiteKernel()')
# Out:
# 0it [00:00, ?it/s]
# GP C(1.0)*Matern() * RBF([1, 1]) + Matern() + WhiteKernel()
# 1757it [14:25,  1.43it/s]
# 3111it [25:19,  2.05it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
# Среднее время работы для 1-го объекта (fit, predict,augmentation): 0.4693987919793026
#  10%|█         | 1/10 [00:03<00:28,  3.22s/it]
# Среднее значение метрики RMSE 0.02771937905629165 +- 0.0014577553600277498
#  20%|██        | 2/10 [00:06<00:25,  3.16s/it]
# Среднее значение метрики MAE 0.01977923083285803 +- 0.000927416924340204
#  30%|███       | 3/10 [00:09<00:21,  3.12s/it]
# Среднее значение метрики RSE 0.44069413547840725 +- 0.006431626843130741
#  40%|████      | 4/10 [00:12<00:18,  3.09s/it]
# Среднее значение метрики RAE 0.3997949153834498 +- 0.0064261049102358175
#  50%|█████     | 5/10 [00:15<00:15,  3.08s/it]
# Среднее значение метрики MAPE 17.564072681287524 +- 0.3590524753570165
#  60%|██████    | 6/10 [00:18<00:12,  3.09s/it]
# ...

# %% [markdown]
# # Selection 10  observations in  each passband

# %%
# %matplotlib inline
import diff_aug_re
from diff_aug_re import aug
from tqdm.auto import tqdm
from importlib import reload
reload(diff_aug_re)
import diff_aug_re
from diff_aug_re import aug

model_names = ['BNN',
               'NF',
               'NN (pytorch)',
               'NN (sklearn)',
               'GP',
               'GP C(1.0)*RBF([1.0, 1.0]) + Matern() + WhiteKernel()',
               'GP C(1.0)*Matern() * RBF([1, 1]) + Matern() + WhiteKernel()']
for model in tqdm(model_names):
    aug(model_name = model)
# Out:
# Количество объектов:  1870
# ...
# 0it [00:00, ?it/s]
# BNN
# 1219it [1:33:04,  4.51s/it]
# 1870it [2:21:45,  4.55s/it]
#   0%|          | 0/10 [00:00<?, ?it/s]
# Среднее время работы для 1-го объекта (fit, predict,augmentation): 4.532428452292866
#  10%|█         | 1/10 [00:01<00:16,  1.84s/it]
# Среднее значение метрики RMSE 0.041101188353625244 +- 0.005033629548531355
#  20%|██        | 2/10 [00:03<00:14,  1.81s/it]
# Среднее значение метрики MAE 0.024439349982020683 +- 0.002447848299147713
#  30%|███       | 3/10 [00:05<00:12,  1.81s/it]
# Среднее значение метрики RSE 0.400081259159578 +- 0.007635505365474324
#  40%|████      | 4/10 [00:07<00:10,  1.80s/it]
# Среднее значение метрики RAE 0.3271507669371078 +- 0.006409292420157968
#  50%|█████     | 5/10 [00:08<00:08,  1.79s/it]
# Среднее значение метрики MAPE 14.993261487382103 +- 0.4751025962352406
#  60%|██████    | 6/10 [00:10<00:07,  1.81s/it]
# Среднее значение метрики NLPD 115.98207545528196 +- 6.141020143233664
# ...
